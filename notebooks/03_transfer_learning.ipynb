# %% [markdown]
# Transfer Learning Notebook Structure:
# Introduction: Why transfer learning should improve upon baseline
#
# Model Selection: EfficientNetB0 vs MobileNetV2 comparison
#
# Two-Stage Training: Feature extraction → Fine-tuning
#
# Performance Comparison: Demonstrate improvement over baseline
#
# Critical Decision Point:
# Based on your "both" class performance (high recall, low precision), you might adjust your transfer learning strategy to use more moderate class weights.
